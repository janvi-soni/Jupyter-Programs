# %%
import numpy as np
import seaborn as sns
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\janvi soni\Desktop\datasets\CO2 Emissions_Canada.csv")
df
# Out:
#        Make        Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 0     ACURA          ILX         COMPACT             2.0          4
# 1     ACURA          ILX         COMPACT             2.4          4
# 2     ACURA   ILX HYBRID         COMPACT             1.5          4
# 3     ACURA      MDX 4WD     SUV - SMALL             3.5          6
# 4     ACURA      RDX AWD     SUV - SMALL             3.5          6
# ...     ...          ...             ...             ...        ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL             2.0          4
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL             2.0          4
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL             2.0          4
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD             2.0          4
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD             2.0          4
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             AS5         Z                               9.9
# ...

# %%
df.drop(["Make","Model","Vehicle Class","Transmission","Fuel Type","Fuel Consumption Comb (mpg)","Fuel Consumption City (L/100 km)","Fuel Consumption Hwy (L/100 km)"],axis=1,inplace=True)

# %%
df
# Out:
#       Engine Size(L)  Cylinders  Fuel Consumption Comb (L/100 km)  \
# 0                2.0          4                               8.5
# 1                2.4          4                               9.6
# 2                1.5          4                               5.9
# 3                3.5          6                              11.1
# 4                3.5          6                              10.6
# ...              ...        ...                               ...
# 7380             2.0          4                               9.4
# 7381             2.0          4                               9.9
# 7382             2.0          4                              10.3
# 7383             2.0          4                               9.9
# 7384             2.0          4                              10.7
#
#       CO2 Emissions(g/km)
# 0                     196
# 1                     221
# 2                     136
# 3                     255
# 4                     244
# ...

# %%
df.isnull().sum()
# Out:
# Engine Size(L)                      0
# Cylinders                           0
# Fuel Consumption Comb (L/100 km)    0
# CO2 Emissions(g/km)                 0
# dtype: int64

# %%
sns.lmplot(data=df,x="Engine Size(L)",y="CO2 Emissions(g/km)")

# %%
xbar=df["Engine Size(L)"].mean()
xbar
# Out:
# 3.160067704807041

# %%
ybar=df["CO2 Emissions(g/km)"].mean()
ybar
# Out:
# 250.58469871360867

# %%
df[["numeratorr"]]=(df["Engine Size(L)"]-xbar)*(df["CO2 Emissions(g/km)"]-ybar)
df
# Out:
#       Engine Size(L)  Cylinders  Fuel Consumption Comb (L/100 km)  \
# 0                2.0          4                               8.5
# 1                2.4          4                               9.6
# 2                1.5          4                               5.9
# 3                3.5          6                              11.1
# 4                3.5          6                              10.6
# ...              ...        ...                               ...
# 7380             2.0          4                               9.4
# 7381             2.0          4                               9.9
# 7382             2.0          4                              10.3
# 7383             2.0          4                               9.9
# 7384             2.0          4                              10.7
#
#       CO2 Emissions(g/km)  numeratorr
# 0                     196   63.321946
# 1                     221   22.486374
# 2                     136  190.218358
# ...

# %%
numerator=df["numeratorr"].sum()
numerator
# Out:
# 497987.42765064316

# %%
df[["denominatorr"]]=(df["Engine Size(L)"]-xbar)*(df["Engine Size(L)"]-xbar)
df
# Out:
#       Engine Size(L)  Cylinders  Fuel Consumption Comb (L/100 km)  \
# 0                2.0          4                               8.5
# 1                2.4          4                               9.6
# 2                1.5          4                               5.9
# 3                3.5          6                              11.1
# 4                3.5          6                              10.6
# ...              ...        ...                               ...
# 7380             2.0          4                               9.4
# 7381             2.0          4                               9.9
# 7382             2.0          4                              10.3
# 7383             2.0          4                               9.9
# 7384             2.0          4                              10.7
#
#       CO2 Emissions(g/km)  numeratorr  denominatorr
# 0                     196   63.321946      1.345757
# 1                     221   22.486374      0.577703
# ...

# %%
denominator=df["denominatorr"].sum()
denominator
# Out:
# 13540.613966147597

# %%
theta1=numerator//denominator
theta1
# Out:
# 36.0

# %%
theta0=ybar-(theta1*xbar)
theta0
# Out:
# 136.8222613405552

# %%
predicted_value=theta0+(theta1*df["Engine Size(L)"])
predicted_value
# Out:
# 0       208.822261
# 1       223.222261
# 2       190.822261
# 3       262.822261
# 4       262.822261
#            ...
# 7380    208.822261
# 7381    208.822261
# 7382    208.822261
# 7383    208.822261
# 7384    208.822261
# Name: Engine Size(L), Length: 7385, dtype: float64

# %%
df[["Engine Size(L)","CO2 Emissions(g/km)"]].head(10)
# Out:
#    Engine Size(L)  CO2 Emissions(g/km)
# 0             2.0                  196
# 1             2.4                  221
# 2             1.5                  136
# 3             3.5                  255
# 4             3.5                  244
# 5             3.5                  230
# 6             3.5                  232
# 7             3.7                  255
# 8             3.7                  267
# 9             2.4                  212

# %%
df.drop(["numeratorr","denominatorr"],axis=1,inplace=True)
df
# Out:
#       Engine Size(L)  Cylinders  Fuel Consumption Comb (L/100 km)  \
# 0                2.0          4                               8.5
# 1                2.4          4                               9.6
# 2                1.5          4                               5.9
# 3                3.5          6                              11.1
# 4                3.5          6                              10.6
# ...              ...        ...                               ...
# 7380             2.0          4                               9.4
# 7381             2.0          4                               9.9
# 7382             2.0          4                              10.3
# 7383             2.0          4                               9.9
# 7384             2.0          4                              10.7
#
#       CO2 Emissions(g/km)
# 0                     196
# 1                     221
# 2                     136
# 3                     255
# 4                     244
# ...

# %%
 # creating the object of linear regression class

# %%
# above prediction is manually(by using formula and all) but now we will do prediction by predefined methods of scikit learn
from sklearn.linear_model import LinearRegression   # provide a linear regression model for prediction
from sklearn.metrics import r2_score               # for finding accuracy
from sklearn.model_selection import train_test_split #split the dataset for training and testing
from sklearn.preprocessing import StandardScaler,PolynomialFeatures # standardscalar-for scaling the data after performing standardization and all

# %%
x=df[["Engine Size(L)"]] #x contains the whole column  of engine size
y=df[["CO2 Emissions(g/km)"]] # y contain the whole column of c02 emission
slr=LinearRegression()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=6200)# split the data for training and testing

# %%
ss=StandardScaler() #object creation
x_train=ss.fit_transform(x_train)

# %%
slr.fit(x_train,y_train) #train the model
x_test=ss.fit_transform(x_test) #fit find the mean and variance etc and transformmethod transform the testingdata of engine size according to mean 
ypred=slr.predict(x_test) #predict method takes the transformed data of feature(engine_size) and generate a response(co2_emission)
ypred
# Out:
# array([[274.30744805],
#        [207.70650858],
#        [192.90629981],
#        ...,
#        [192.90629981],
#        [329.80823094],
#        [329.80823094]])

# %%
accuracyoftrainmodel=slr.score(x_train,y_train)
accuracy=r2_score(ypred,y_test)

# %%
accuracyoftrainmodel
# Out:
# 0.731483226468024

# %%
accuracy
# Out:
# 0.5910714734975057
